# %%
import pandas as pd
import numpy as np


btradron = pd.read_csv("./.data/BTRADRON.csv", skiprows=16)

btradron["Currency"] = "RON"

btradeur = pd.read_csv("./.data/BTRADEUR.csv", skiprows=16)

btradeur["Currency"] = "EUR"


df = pd.concat([btradron, btradeur], ignore_index=True)

df.head()
# Out:
#   Data tranzactie Data valuta  \
# 0      2024-08-02  2024-08-02
# 1      2024-08-01  2024-08-01
# 2      2024-07-31  2024-07-31
# 3      2024-07-22  2024-07-22
# 4      2024-07-22  2024-07-22
#
#                                            Descriere Referinta tranzactiei  \
# 0  Plata la POS non-BT cu card VISA;EPOS 30/07/20...      000NVPO242154Boq
# 1  Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...      E41IZ56241800002
# 2  Plata la POS non-BT cu card VISA;EPOS 28/07/20...      000NVPO242134gxY
# 3  Plata OP inter - canal electronic;/ROC/./RFB/2...      E41ZEXA2420400GK
# 4  Comision plata OP;/ROC/./RFB/20240722/20240722...      E41ZEXA2420400GK
#
#        Debit  Credit Sold contabil Currency
# 0  -1,043.83     NaN        164.30      RON
# 1     -29.00     NaN      1,208.13      RON
# 2     -36.99     NaN      1,237.13      RON
# 3  -1,301.00     NaN        535.52      RON
# 4      -5.00     NaN      1,836.52      RON

# %%
df = df.drop(
    ["Referinta tranzactiei", "Credit", "Sold contabil", "Data valuta"], axis=1
)

df.head()
# Out:
#   Data tranzactie                                          Descriere  \
# 0      2024-08-02  Plata la POS non-BT cu card VISA;EPOS 30/07/20...
# 1      2024-08-01  Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...
# 2      2024-07-31  Plata la POS non-BT cu card VISA;EPOS 28/07/20...
# 3      2024-07-22  Plata OP inter - canal electronic;/ROC/./RFB/2...
# 4      2024-07-22  Comision plata OP;/ROC/./RFB/20240722/20240722...
#
#        Debit Currency
# 0  -1,043.83      RON
# 1     -29.00      RON
# 2     -36.99      RON
# 3  -1,301.00      RON
# 4      -5.00      RON

# %%
df["Payment Date"] = df["Descriere"].str.extract(r"(POS\s(\d{2}\/\d{2}\/\d{4}))")[1]
regex_pattern = r"Schimb valutar|LT383250069969855031|Comision"

mask = ~df["Descriere"].str.contains(regex_pattern)


filtered_df = df.loc[mask].copy()


date_formats = ["%d/%m/%Y", "%Y-%m-%d", "%d-%m-%Y"]  # Add all expected formats
for fmt in date_formats:
    filtered_df["Payment Date"] = pd.to_datetime(
        filtered_df["Payment Date"], format=fmt, errors="coerce"
    )


filtered_df["Data tranzactie"] = pd.to_datetime(df["Data tranzactie"], errors="coerce")

# Formatting dates to 'day-month-year'
filtered_df["Payment Date"] = filtered_df["Payment Date"].dt.strftime("%d-%m-%Y")
filtered_df["Data tranzactie"] = filtered_df["Data tranzactie"].dt.strftime("%d-%m-%Y")


filtered_df["Payment Date"] = filtered_df["Payment Date"].fillna(
    filtered_df["Data tranzactie"]
)


filtered_df.head()
# Out:
#   Data tranzactie                                          Descriere  \
# 0      02-08-2024  Plata la POS non-BT cu card VISA;EPOS 30/07/20...
# 1      01-08-2024  Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...
# 2      31-07-2024  Plata la POS non-BT cu card VISA;EPOS 28/07/20...
# 3      22-07-2024  Plata OP inter - canal electronic;/ROC/./RFB/2...
# 5      07-07-2024  Plata la POS non-BT cu card VISA;EPOS 05/07/20...
#
#        Debit Currency Payment Date
# 0  -1,043.83      RON   30-07-2024
# 1     -29.00      RON   01-08-2024
# 2     -36.99      RON   28-07-2024
# 3  -1,301.00      RON   22-07-2024
# 5     -49.99      RON   05-07-2024

# %%
filtered_df["Merchant"] = filtered_df["Descriere"].str.extract(
    r"TID:\s*(?:[^\s]{2,8}\s+)?(\w+)"
)
filtered_df["Merchant"] = filtered_df["Merchant"].fillna(
    df["Descriere"].str.split(";").str[3]
)

# %%
filtered_df['Payment Date'] = pd.to_datetime(filtered_df['Payment Date'], errors='coerce', dayfirst=True)
filtered_df = filtered_df.sort_values(by="Payment Date", ascending=True)
filtered_df
# Out:
#    Data tranzactie                                          Descriere  \
# 5       07-07-2024  Plata la POS non-BT cu card VISA;EPOS 05/07/20...
# 49      10-07-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 08...
# 46      12-07-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 10...
# 45      14-07-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 12...
# 42      17-07-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 15...
# 41      18-07-2024  Plata la POS non-BT cu card MASTERCARD;POS 16/...
# 40      19-07-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 17...
# 39      19-07-2024  Plata la POS non-BT cu card MASTERCARD;POS 17/...
# 36      20-07-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 18...
# 38      20-07-2024  Retragere de numerar de la ATM non-BT cu card ...
# 28      23-07-2024  Plata la POS non-BT cu card MASTERCARD;POS 21/...
# 3       22-07-2024  Plata OP inter - canal electronic;/ROC/./RFB/2...
# 21      25-07-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 23...
# 20      25-07-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 23...
# 23      24-07-2024  Plata SEPA - Echannel;3911356656391;154;bol.co...
# 25      24-07-2024  Plata SEPA - Echannel;3911356656389;152;bol.co...
# 27      24-07-2024  Plata SEPA - Echannel;3911319447674;151;bol.co...
# 17      26-07-2024  Plata la POS non-BT cu card MASTERCARD;POS 24/...
# 16      27-07-2024  Plata SEPA - Echannel;Booking 44129781 RADULES...
# 2       31-07-2024  Plata la POS non-BT cu card VISA;EPOS 28/07/20...
# 11      01-08-2024  Plata la POS non-BT cu card MASTERCARD;POS 29/...
# 12      01-08-2024  Plata la POS non-BT cu card MASTERCARD;POS 30/...
# 0       02-08-2024  Plata la POS non-BT cu card VISA;EPOS 30/07/20...
# 10      02-08-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 31...
# 9       03-08-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 01...
# 1       01-08-2024  Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...
# 8       04-08-2024  Plata la POS non-BT cu card MASTERCARD;EPOS 02...
# 7       04-08-2024  Plata la POS non-BT cu card MASTERCARD;POS 03/...
# 6       04-08-2024  Plata la POS non-BT cu card MASTERCARD;POS 03/...
#
#         Debit Currency Payment Date                    Merchant
# 5      -49.99      RON   2024-07-05                       APPLE
# 49     -33.05      EUR   2024-07-08                    LINKEDIN
# 46     -12.27      EUR   2024-07-10                      Amazon
# 45     -11.07      EUR   2024-07-12                      Amazon
# 42     -39.80      EUR   2024-07-15                   NESPRESSO
# 41     -15.00      EUR   2024-07-16                      Krefel
# 40     -14.91      EUR   2024-07-17                        AMZN
# 39     -30.02      EUR   2024-07-17                          Q8
# 36     -42.00      EUR   2024-07-18                        AMZN
# 38     -20.00      EUR   2024-07-20                      JAMBES
# 28     -40.62      EUR   2024-07-21                 INTERMARCHE
# 3   -1,301.00      RON   2024-07-22  BUGETUL GENERAL CONSOLIDAT
# 21     -38.55      EUR   2024-07-23                        AMZN
# 20     -66.95      EUR   2024-07-23                        UBER
# 23      -2.99      EUR   2024-07-24                     bol.com
# 25     -17.98      EUR   2024-07-24                     bol.com
# 27    -158.79      EUR   2024-07-24                     bol.com
# 17     -73.00      EUR   2024-07-24                    DELHAIZE
# 16  -1,945.00      EUR   2024-07-27                TRYFON AEVKE
# 2      -36.99      RON   2024-07-28                       APPLE
# 11     -13.91      EUR   2024-07-29                          Q8
# 12     -67.92      EUR   2024-07-30                    DELHAIZE
# 0   -1,043.83      RON   2024-07-30                         PPC
# 10     -20.29      EUR   2024-07-31                        AMZN
# 9      -13.80      EUR   2024-08-01                      GOOGLE
# 1      -29.00      RON   2024-08-01                         NaN
# 8      -21.90      EUR   2024-08-02                   NESPRESSO
# 7      -46.49      EUR   2024-08-03                    DELHAIZE
# 6       -9.15      EUR   2024-08-03                 Boulangerie

# %%
new_column_order = ["Payment Date", "Merchant", "Descriere", "Debit", "Data tranzactie", "Currency"]

filtered_df = filtered_df[new_column_order]

filtered_df["Payment Date"] = pd.to_datetime(df["Payment Date"], errors="coerce")

filtered_df
# Out:
# /tmp/ipykernel_84900/3861002688.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   filtered_df["Payment Date"] = pd.to_datetime(df["Payment Date"], errors="coerce")
#    Payment Date                    Merchant  \
# 5    2024-07-05                       APPLE
# 49   2024-07-08                    LINKEDIN
# 46   2024-07-10                      Amazon
# 45   2024-07-12                      Amazon
# 42   2024-07-15                   NESPRESSO
# 41   2024-07-16                      Krefel
# 40   2024-07-17                        AMZN
# 39   2024-07-17                          Q8
# 36   2024-07-18                        AMZN
# 38          NaT                      JAMBES
# 28   2024-07-21                 INTERMARCHE
# 3           NaT  BUGETUL GENERAL CONSOLIDAT
# 21   2024-07-23                        AMZN
# 20   2024-07-23                        UBER
# 23          NaT                     bol.com
# 25          NaT                     bol.com
# 27          NaT                     bol.com
# 17   2024-07-24                    DELHAIZE
# 16          NaT                TRYFON AEVKE
# 2    2024-07-28                       APPLE
# 11   2024-07-29                          Q8
# 12   2024-07-30                    DELHAIZE
# 0    2024-07-30                         PPC
# 10   2024-07-31                        AMZN
# 9    2024-08-01                      GOOGLE
# 1           NaT                         NaN
# 8    2024-08-02                   NESPRESSO
# 7    2024-08-03                    DELHAIZE
# 6    2024-08-03                 Boulangerie
#
#                                             Descriere      Debit  \
# 5   Plata la POS non-BT cu card VISA;EPOS 05/07/20...     -49.99
# 49  Plata la POS non-BT cu card MASTERCARD;EPOS 08...     -33.05
# 46  Plata la POS non-BT cu card MASTERCARD;EPOS 10...     -12.27
# 45  Plata la POS non-BT cu card MASTERCARD;EPOS 12...     -11.07
# 42  Plata la POS non-BT cu card MASTERCARD;EPOS 15...     -39.80
# 41  Plata la POS non-BT cu card MASTERCARD;POS 16/...     -15.00
# 40  Plata la POS non-BT cu card MASTERCARD;EPOS 17...     -14.91
# 39  Plata la POS non-BT cu card MASTERCARD;POS 17/...     -30.02
# 36  Plata la POS non-BT cu card MASTERCARD;EPOS 18...     -42.00
# 38  Retragere de numerar de la ATM non-BT cu card ...     -20.00
# 28  Plata la POS non-BT cu card MASTERCARD;POS 21/...     -40.62
# 3   Plata OP inter - canal electronic;/ROC/./RFB/2...  -1,301.00
# 21  Plata la POS non-BT cu card MASTERCARD;EPOS 23...     -38.55
# 20  Plata la POS non-BT cu card MASTERCARD;EPOS 23...     -66.95
# 23  Plata SEPA - Echannel;3911356656391;154;bol.co...      -2.99
# 25  Plata SEPA - Echannel;3911356656389;152;bol.co...     -17.98
# 27  Plata SEPA - Echannel;3911319447674;151;bol.co...    -158.79
# 17  Plata la POS non-BT cu card MASTERCARD;POS 24/...     -73.00
# 16  Plata SEPA - Echannel;Booking 44129781 RADULES...  -1,945.00
# 2   Plata la POS non-BT cu card VISA;EPOS 28/07/20...     -36.99
# 11  Plata la POS non-BT cu card MASTERCARD;POS 29/...     -13.91
# 12  Plata la POS non-BT cu card MASTERCARD;POS 30/...     -67.92
# 0   Plata la POS non-BT cu card VISA;EPOS 30/07/20...  -1,043.83
# 10  Plata la POS non-BT cu card MASTERCARD;EPOS 31...     -20.29
# 9   Plata la POS non-BT cu card MASTERCARD;EPOS 01...     -13.80
# 1   Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...     -29.00
# 8   Plata la POS non-BT cu card MASTERCARD;EPOS 02...     -21.90
# 7   Plata la POS non-BT cu card MASTERCARD;POS 03/...     -46.49
# 6   Plata la POS non-BT cu card MASTERCARD;POS 03/...      -9.15
#
#    Data tranzactie Currency
# 5       07-07-2024      RON
# 49      10-07-2024      EUR
# 46      12-07-2024      EUR
# 45      14-07-2024      EUR
# 42      17-07-2024      EUR
# 41      18-07-2024      EUR
# 40      19-07-2024      EUR
# 39      19-07-2024      EUR
# 36      20-07-2024      EUR
# 38      20-07-2024      EUR
# 28      23-07-2024      EUR
# 3       22-07-2024      RON
# 21      25-07-2024      EUR
# 20      25-07-2024      EUR
# 23      24-07-2024      EUR
# 25      24-07-2024      EUR
# 27      24-07-2024      EUR
# 17      26-07-2024      EUR
# 16      27-07-2024      EUR
# 2       31-07-2024      RON
# 11      01-08-2024      EUR
# 12      01-08-2024      EUR
# 0       02-08-2024      RON
# 10      02-08-2024      EUR
# 9       03-08-2024      EUR
# 1       01-08-2024      RON
# 8       04-08-2024      EUR
# 7       04-08-2024      EUR
# 6       04-08-2024      EUR
