# %%
import pandas as pd
import numpy as np


btradron = pd.read_csv("/home/mihnearad/Development/BankingInfo-Parse-Script/.data/BTRADRON.csv", skiprows=16)

btradron["Currency"] = "RON"

btradeur = pd.read_csv("/home/mihnearad/Development/BankingInfo-Parse-Script/.data/BTRADEUR.csv", skiprows=16)

btradeur["Currency"] = "EUR"


df = pd.concat([btradron, btradeur], ignore_index=True)

df.head()
# Out:
#   Data tranzactie Data valuta  \
# 0      2024-08-08  2024-08-08
# 1      2024-08-02  2024-08-02
# 2      2024-08-01  2024-08-01
# 3      2024-07-31  2024-07-31
# 4      2024-07-22  2024-07-22
#
#                                            Descriere Referinta tranzactiei  \
# 0  Plata la POS non-BT cu card VISA;EPOS 05/08/20...      000NVPO242214qI3
# 1  Plata la POS non-BT cu card VISA;EPOS 30/07/20...      000NVPO242154Boq
# 2  Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...      E41IZ56241800002
# 3  Plata la POS non-BT cu card VISA;EPOS 28/07/20...      000NVPO242134gxY
# 4  Plata OP inter - canal electronic;/ROC/./RFB/2...      E41ZEXA2420400GK
#
#        Debit  Credit Sold contabil Currency
# 0     -49.99     NaN        114.31      RON
# 1  -1,043.83     NaN        164.30      RON
# 2     -29.00     NaN      1,208.13      RON
# 3     -36.99     NaN      1,237.13      RON
# 4  -1,301.00     NaN        535.52      RON

# %%
df = df.drop(
    ["Referinta tranzactiei", "Credit", "Sold contabil", "Data valuta"], axis=1
)

df.head()
# Out:
#   Data tranzactie                                          Descriere  \
# 0      2024-08-08  Plata la POS non-BT cu card VISA;EPOS 05/08/20...
# 1      2024-08-02  Plata la POS non-BT cu card VISA;EPOS 30/07/20...
# 2      2024-08-01  Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...
# 3      2024-07-31  Plata la POS non-BT cu card VISA;EPOS 28/07/20...
# 4      2024-07-22  Plata OP inter - canal electronic;/ROC/./RFB/2...
#
#        Debit Currency
# 0     -49.99      RON
# 1  -1,043.83      RON
# 2     -29.00      RON
# 3     -36.99      RON
# 4  -1,301.00      RON

# %%
df["Payment Date"] = df["Descriere"].str.extract(r"(POS\s(\d{2}\/\d{2}\/\d{4}))")[1]
regex_pattern = r"Schimb valutar|LT383250069969855031|Comision"

mask = ~df["Descriere"].str.contains(regex_pattern)


filtered_df = df.loc[mask].copy()


date_formats = ["%d/%m/%Y", "%Y-%m-%d", "%d-%m-%Y"]  # Add all expected formats
for fmt in date_formats:
    filtered_df["Payment Date"] = pd.to_datetime(
        filtered_df["Payment Date"], format=fmt, errors="coerce"
    )


filtered_df["Data tranzactie"] = pd.to_datetime(df["Data tranzactie"], errors="coerce")

# Formatting dates to 'day-month-year'
filtered_df["Payment Date"] = filtered_df["Payment Date"].dt.strftime("%d-%m-%Y")
filtered_df["Data tranzactie"] = filtered_df["Data tranzactie"].dt.strftime("%d-%m-%Y")


filtered_df["Payment Date"] = filtered_df["Payment Date"].fillna(
    filtered_df["Data tranzactie"]
)


filtered_df.head()
# Out:
#   Data tranzactie                                          Descriere  \
# 0      08-08-2024  Plata la POS non-BT cu card VISA;EPOS 05/08/20...
# 1      02-08-2024  Plata la POS non-BT cu card VISA;EPOS 30/07/20...
# 2      01-08-2024  Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...
# 3      31-07-2024  Plata la POS non-BT cu card VISA;EPOS 28/07/20...
# 4      22-07-2024  Plata OP inter - canal electronic;/ROC/./RFB/2...
#
#        Debit Currency Payment Date
# 0     -49.99      RON   05-08-2024
# 1  -1,043.83      RON   30-07-2024
# 2     -29.00      RON   01-08-2024
# 3     -36.99      RON   28-07-2024
# 4  -1,301.00      RON   22-07-2024

# %%
filtered_df["Merchant"] = filtered_df["Descriere"].str.extract(
    r"TID:\s*(?:[^\s]{2,8}\s+)?(\w+)"
)
filtered_df["Merchant"] = filtered_df["Merchant"].fillna(
    df["Descriere"].str.split(";").str[3]
)

filtered_df.head()
# Out:
#   Data tranzactie                                          Descriere  \
# 0      08-08-2024  Plata la POS non-BT cu card VISA;EPOS 05/08/20...
# 1      02-08-2024  Plata la POS non-BT cu card VISA;EPOS 30/07/20...
# 2      01-08-2024  Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...
# 3      31-07-2024  Plata la POS non-BT cu card VISA;EPOS 28/07/20...
# 4      22-07-2024  Plata OP inter - canal electronic;/ROC/./RFB/2...
#
#        Debit Currency Payment Date                    Merchant
# 0     -49.99      RON   05-08-2024                       APPLE
# 1  -1,043.83      RON   30-07-2024                         PPC
# 2     -29.00      RON   01-08-2024                         NaN
# 3     -36.99      RON   28-07-2024                       APPLE
# 4  -1,301.00      RON   22-07-2024  BUGETUL GENERAL CONSOLIDAT

# %%
# Assuming filtered_df is already loaded with your data

# Convert 'Payment Date' to datetime type ensuring all entries are checked and properly interpreted
filtered_df['Payment Date'] = pd.to_datetime(filtered_df['Payment Date'], errors='coerce', dayfirst=True)

# Convert 'Data tranzactie' to datetime type as well
filtered_df['Data tranzactie'] = pd.to_datetime(filtered_df['Data tranzactie'], errors='coerce', dayfirst=True)

# If you need to display dates in 'DD-MM-YYYY' format, convert datetime objects to strings in the desired format
filtered_df['Formatted Payment Date'] = filtered_df['Payment Date'].dt.strftime('%d-%m-%Y')
filtered_df['Formatted Data Tranzactie'] = filtered_df['Data tranzactie'].dt.strftime('%d-%m-%Y')

# Sort the DataFrame by 'Payment Date'
filtered_df = filtered_df.sort_values(by='Payment Date', ascending=True)

# Now, you can drop the old date columns if they are no longer needed, or keep them as is
# filtered_df.drop(columns=['Payment Date', 'Data tranzactie'], inplace=True)

# Optionally, reorder columns to include the formatted date columns
new_column_order = ['Formatted Payment Date', 'Merchant', 'Descriere', 'Debit', 'Currency']
filtered_df = filtered_df[new_column_order]

filtered_df.head()
# Out:
#    Formatted Payment Date   Merchant  \
# 64             04-07-2024      Namur
# 65             04-07-2024       AMZN
# 67             05-07-2024        142
# 63             05-07-2024  Microsoft
# 6              05-07-2024      APPLE
#
#                                             Descriere    Debit Currency
# 64  Plata la POS non-BT cu card MASTERCARD;EPOS 04...   -45.09      EUR
# 65  Plata la POS non-BT cu card MASTERCARD;EPOS 04...    -7.82      EUR
# 67  Plata instant EUR;diurna;;142;mihnea radulescu...  -100.00      EUR
# 63  Plata la POS non-BT cu card MASTERCARD;EPOS 05...   -15.40      EUR
# 6   Plata la POS non-BT cu card VISA;EPOS 05/07/20...   -49.99      RON

# %%
filtered_df = filtered_df.rename(
    columns={
        "Formatted Payment Date": "Payment Date",
        "Merchant": "Merchant",
        "Descriere": "Description",
        "Debit": "Debit",
        "Fee Currency": "Currency",
    }
)

filtered_df['Payment Date'] = pd.to_datetime(filtered_df['Payment Date'], format='%d-%m-%Y', errors='coerce')

filtered_df["Account"]="BT Business"

filtered_df
# Out:
#    Payment Date                    Merchant  \
# 64   2024-07-04                       Namur
# 65   2024-07-04                        AMZN
# 67   2024-07-05                         142
# 63   2024-07-05                   Microsoft
# 6    2024-07-05                       APPLE
# 58   2024-07-05                    DELHAIZE
# 57   2024-07-05                          Q8
# 60   2024-07-06                           1
# 56   2024-07-06                          Q8
# 53   2024-07-08                    LINKEDIN
# 50   2024-07-10                      Amazon
# 49   2024-07-12                      Amazon
# 46   2024-07-15                   NESPRESSO
# 45   2024-07-16                      Krefel
# 44   2024-07-17                        AMZN
# 43   2024-07-17                          Q8
# 40   2024-07-18                        AMZN
# 42   2024-07-20                      JAMBES
# 32   2024-07-21                 INTERMARCHE
# 4    2024-07-22  BUGETUL GENERAL CONSOLIDAT
# 24   2024-07-23                        UBER
# 25   2024-07-23                        AMZN
# 27   2024-07-24                     bol.com
# 29   2024-07-24                     bol.com
# 21   2024-07-24                    DELHAIZE
# 31   2024-07-24                     bol.com
# 20   2024-07-27                TRYFON AEVKE
# 3    2024-07-28                       APPLE
# 15   2024-07-29                          Q8
# 16   2024-07-30                    DELHAIZE
# 1    2024-07-30                         PPC
# 14   2024-07-31                        AMZN
# 13   2024-08-01                      GOOGLE
# 2    2024-08-01                         NaN
# 12   2024-08-02                   NESPRESSO
# 11   2024-08-03                    DELHAIZE
# 10   2024-08-03                 Boulangerie
# 0    2024-08-05                       APPLE
# 7    2024-08-06                    DELHAIZE
# 9    2024-08-07                         153
#
#                                           Description      Debit Currency  \
# 64  Plata la POS non-BT cu card MASTERCARD;EPOS 04...     -45.09      EUR
# 65  Plata la POS non-BT cu card MASTERCARD;EPOS 04...      -7.82      EUR
# 67  Plata instant EUR;diurna;;142;mihnea radulescu...    -100.00      EUR
# 63  Plata la POS non-BT cu card MASTERCARD;EPOS 05...     -15.40      EUR
# 6   Plata la POS non-BT cu card VISA;EPOS 05/07/20...     -49.99      RON
# 58  Plata la POS non-BT cu card MASTERCARD;POS 05/...     -66.28      EUR
# 57  Plata la POS non-BT cu card MASTERCARD;POS 05/...     -17.49      EUR
# 60  Plata instant EUR;Diurna;;1;mihnea radulescu;L...     -50.00      EUR
# 56  Plata la POS non-BT cu card MASTERCARD;POS 06/...     -45.03      EUR
# 53  Plata la POS non-BT cu card MASTERCARD;EPOS 08...     -33.05      EUR
# 50  Plata la POS non-BT cu card MASTERCARD;EPOS 10...     -12.27      EUR
# 49  Plata la POS non-BT cu card MASTERCARD;EPOS 12...     -11.07      EUR
# 46  Plata la POS non-BT cu card MASTERCARD;EPOS 15...     -39.80      EUR
# 45  Plata la POS non-BT cu card MASTERCARD;POS 16/...     -15.00      EUR
# 44  Plata la POS non-BT cu card MASTERCARD;EPOS 17...     -14.91      EUR
# 43  Plata la POS non-BT cu card MASTERCARD;POS 17/...     -30.02      EUR
# 40  Plata la POS non-BT cu card MASTERCARD;EPOS 18...     -42.00      EUR
# 42  Retragere de numerar de la ATM non-BT cu card ...     -20.00      EUR
# 32  Plata la POS non-BT cu card MASTERCARD;POS 21/...     -40.62      EUR
# 4   Plata OP inter - canal electronic;/ROC/./RFB/2...  -1,301.00      RON
# 24  Plata la POS non-BT cu card MASTERCARD;EPOS 23...     -66.95      EUR
# 25  Plata la POS non-BT cu card MASTERCARD;EPOS 23...     -38.55      EUR
# 27  Plata SEPA - Echannel;3911356656391;154;bol.co...      -2.99      EUR
# 29  Plata SEPA - Echannel;3911356656389;152;bol.co...     -17.98      EUR
# 21  Plata la POS non-BT cu card MASTERCARD;POS 24/...     -73.00      EUR
# 31  Plata SEPA - Echannel;3911319447674;151;bol.co...    -158.79      EUR
# 20  Plata SEPA - Echannel;Booking 44129781 RADULES...  -1,945.00      EUR
# 3   Plata la POS non-BT cu card VISA;EPOS 28/07/20...     -36.99      RON
# 15  Plata la POS non-BT cu card MASTERCARD;POS 29/...     -13.91      EUR
# 16  Plata la POS non-BT cu card MASTERCARD;POS 30/...     -67.92      EUR
# 1   Plata la POS non-BT cu card VISA;EPOS 30/07/20...  -1,043.83      RON
# 14  Plata la POS non-BT cu card MASTERCARD;EPOS 31...     -20.29      EUR
# 13  Plata la POS non-BT cu card MASTERCARD;EPOS 01...     -13.80      EUR
# 2   Pachet IZI;Nelimitat in reteaua BT;REF: E41IZ5...     -29.00      RON
# 12  Plata la POS non-BT cu card MASTERCARD;EPOS 02...     -21.90      EUR
# 11  Plata la POS non-BT cu card MASTERCARD;POS 03/...     -46.49      EUR
# 10  Plata la POS non-BT cu card MASTERCARD;POS 03/...      -9.15      EUR
# 0   Plata la POS non-BT cu card VISA;EPOS 05/08/20...     -49.99      RON
# 7   Plata la POS non-BT cu card MASTERCARD;POS 06/...     -92.18      EUR
# 9   Plata instant EUR;diurna;;153;mihnea radulescu...    -550.00      EUR
#
#         Account
# 64  BT Business
# 65  BT Business
# 67  BT Business
# 63  BT Business
# 6   BT Business
# 58  BT Business
# 57  BT Business
# 60  BT Business
# 56  BT Business
# 53  BT Business
# 50  BT Business
# 49  BT Business
# 46  BT Business
# 45  BT Business
# 44  BT Business
# 43  BT Business
# 40  BT Business
# 42  BT Business
# 32  BT Business
# 4   BT Business
# 24  BT Business
# 25  BT Business
# 27  BT Business
# 29  BT Business
# 21  BT Business
# 31  BT Business
# 20  BT Business
# 3   BT Business
# 15  BT Business
# 16  BT Business
# 1   BT Business
# 14  BT Business
# 13  BT Business
# 2   BT Business
# 12  BT Business
# 11  BT Business
# 10  BT Business
# 0   BT Business
# 7   BT Business
# 9   BT Business

# %%
filtered_df.to_csv("/home/mihnearad/Development/BankingInfo-Parse-Script/.data/filtered/filtered_bt.csv", index=False)
